# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Dependencies and Setup

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
import api_keys
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %%
#pass list to dataframe and preview
cities_df = pd.DataFrame.from_records([cities])
cities_df = cities_df.transpose()
cities_df = cities_df.rename(columns={0:"City"})
cities_df.head()
# Out:
#               City
# 0  arraial do cabo
# 1           albany
# 2          rikitea
# 3       georgetown
# 4            airai

# %% [markdown]
# ### Perform API Calls

# %%
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it's being processed (with the city number and city name).
cities_weather=cities_df
url = "http://api.openweathermap.org/data/2.5/weather?"

row_count = 1

print("Beginning Work on Requests")
for index, row in cities_df.iterrows():
    target_city = row["City"]
    target_url = url + "appid=" + api_key + "&units=IMPERIAL" + "&q=" + target_city.replace(" ","+")
    city_data = requests.get(target_url).json()
    if city_data["cod"] == "404":
        print("Request not found, skipping...")

    else:
        cities_weather.set_value(index, "City", city_data["name"])
        cities_weather.set_value(index, "Country", city_data["sys"]["country"])
        cities_weather.set_value(index, "Temperature (F)", city_data["main"]["temp"])
        cities_weather.set_value(index, "Latitude", city_data["coord"]["lat"])
        cities_weather.set_value(index, "Longitude", city_data["coord"]["lon"])
        cities_weather.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
        cities_weather.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
        cities_weather.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        
        print("------------------------")
        print("Proceesing: Request # " , row_count, ' | ' , city_data["name"], city_data["sys"]["country"])
        print(target_url)
        row_count += 1
# Out:
# Beginning Work on Requests
# ------------------------
# Proceesing: Request #  1  |  Arraial do Cabo BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=arraial+do+cabo
# ------------------------
# Proceesing: Request #  2  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: Request #  3  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: Request #  4  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: Request #  5  |  Airai TL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=airai
# ------------------------
# Proceesing: Request #  6  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: Request #  7  |  Gamba CN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=gamba
# ------------------------
# Proceesing: Request #  8  |  Peniche PT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=peniche
# ------------------------
# Proceesing: Request #  9  |  Kloulklubed PW
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kloulklubed
# ------------------------
# Proceesing: Request #  10  |  Port Hardy CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=port+hardy
# ------------------------
# Proceesing: Request #  11  |  Tuktoyaktuk CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tuktoyaktuk
# ------------------------
# Proceesing: Request #  12  |  Katsuura JP
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=katsuura
# ------------------------
# Proceesing: Request #  13  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=chuy
# ------------------------
# Proceesing: Request #  14  |  Teya MX
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=teya
# ------------------------
# Proceesing: Request #  15  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=hilo
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  16  |  Rimouski CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=rimouski
# ------------------------
# Proceesing: Request #  17  |  Chumikan RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=chumikan
# ------------------------
# Proceesing: Request #  18  |  Kabo CF
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kabo
# ------------------------
# Proceesing: Request #  19  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=yellowknife
# ------------------------
# Proceesing: Request #  20  |  Brandon US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=brandon
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  21  |  Evensk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=evensk
# ------------------------
# Proceesing: Request #  22  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=punta+arenas
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  23  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=avarua
# ------------------------
# Proceesing: Request #  24  |  Sur OM
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sur
# ------------------------
# Proceesing: Request #  25  |  Bambous Virieux MU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bambous+virieux
# ------------------------
# Proceesing: Request #  26  |  Bemidji US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bemidji
# ------------------------
# Proceesing: Request #  27  |  Fort Saint James CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=fort+saint+james
# ------------------------
# Proceesing: Request #  28  |  Mitsamiouli KM
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mitsamiouli
# ------------------------
# Proceesing: Request #  29  |  Anloga GH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=anloga
# ------------------------
# Proceesing: Request #  30  |  Mahebourg MU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mahebourg
# ------------------------
# Proceesing: Request #  31  |  Faanui PF
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=faanui
# ------------------------
# Proceesing: Request #  32  |  Burnie AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=burnie
# ------------------------
# Proceesing: Request #  33  |  Tuatapere NZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tuatapere
# ------------------------
# Proceesing: Request #  34  |  Lagoa PT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=lagoa
# ------------------------
# Proceesing: Request #  35  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=lebu
# ------------------------
# Proceesing: Request #  36  |  Portales US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=portales
# ------------------------
# Proceesing: Request #  37  |  Vestmanna FO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vestmanna
# ------------------------
# Proceesing: Request #  38  |  Richards Bay ZA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=richards+bay
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  39  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: Request #  40  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: Request #  41  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: Request #  42  |  Upernavik GL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=upernavik
# ------------------------
# Proceesing: Request #  43  |  Kapuskasing CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kapuskasing
# ------------------------
# Proceesing: Request #  44  |  Yerbogachen RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=yerbogachen
# ------------------------
# Proceesing: Request #  45  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=atuona
# ------------------------
# Proceesing: Request #  46  |  Alyangula AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=alyangula
# ------------------------
# Proceesing: Request #  47  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: Request #  48  |  Husavik CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=husavik
# ------------------------
# Proceesing: Request #  49  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=new+norfolk
# Request not found, skipping...
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  50  |  Komsomolskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=komsomolskiy
# ------------------------
# Proceesing: Request #  51  |  Duluth US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=duluth
# ------------------------
# Proceesing: Request #  52  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=khatanga
# ------------------------
# Proceesing: Request #  53  |  Half Moon Bay US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=half+moon+bay
# ------------------------
# Proceesing: Request #  54  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=victoria
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  55  |  Grand-Santi GF
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=grand-santi
# ------------------------
# Proceesing: Request #  56  |  Ornskoldsvik SE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ornskoldsvik
# ------------------------
# Proceesing: Request #  57  |  Bourail NC
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bourail
# ------------------------
# Proceesing: Request #  58  |  Kikinda RS
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kikinda
# Request not found, skipping...
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  59  |  Muscat OM
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=muscat
# ------------------------
# Proceesing: Request #  60  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=saint-philippe
# ------------------------
# Proceesing: Request #  61  |  Thompson CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=thompson
# ------------------------
# Proceesing: Request #  62  |  East London ZA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=east+london
# ------------------------
# Proceesing: Request #  63  |  Krasnoslobodsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=krasnoslobodsk
# ------------------------
# Proceesing: Request #  64  |  Tupik RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tupik
# ------------------------
# Proceesing: Request #  65  |  Fortuna ES
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=fortuna
# ------------------------
# Proceesing: Request #  66  |  Mar del Plata AR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mar+del+plata
# ------------------------
# Proceesing: Request #  67  |  Hithadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=hithadhoo
# ------------------------
# Proceesing: Request #  68  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: Request #  69  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: Request #  70  |  Alihe CN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=alihe
# ------------------------
# Proceesing: Request #  71  |  Kavieng PG
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kavieng
# ------------------------
# Proceesing: Request #  72  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=barrow
# ------------------------
# Proceesing: Request #  73  |  Tucupita VE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tucupita
# ------------------------
# Proceesing: Request #  74  |  San Giuseppe Jato IT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=san+giuseppe+jato
# ------------------------
# Proceesing: Request #  75  |  Awbari LY
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=awbari
# ------------------------
# Proceesing: Request #  76  |  Iquique CL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=iquique
# Request not found, skipping...
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  77  |  Mathathane BW
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mathathane
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  78  |  Huarmey PE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=huarmey
# ------------------------
# Proceesing: Request #  79  |  Toul FR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=toul
# ------------------------
# Proceesing: Request #  80  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=hobart
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  81  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: Request #  82  |  Bundaberg AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bundaberg
# ------------------------
# Proceesing: Request #  83  |  Ola RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ola
# ------------------------
# Proceesing: Request #  84  |  Pisco PE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=pisco
# ------------------------
# Proceesing: Request #  85  |  Corbi RO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=corbi
# ------------------------
# Proceesing: Request #  86  |  Canon City US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=canon+city
# ------------------------
# Proceesing: Request #  87  |  Whitehorse CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=whitehorse
# ------------------------
# Proceesing: Request #  88  |  Nanortalik GL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=nanortalik
# ------------------------
# Proceesing: Request #  89  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: Request #  90  |  Codrington AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=codrington
# ------------------------
# Proceesing: Request #  91  |  San Patricio PY
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=san+patricio
# ------------------------
# Proceesing: Request #  92  |  Svetlaya RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=svetlaya
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  93  |  Bend US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bend
# ------------------------
# Proceesing: Request #  94  |  Tete MZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tete
# ------------------------
# Proceesing: Request #  95  |  Vestmannaeyjar IS
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vestmannaeyjar
# ------------------------
# Proceesing: Request #  96  |  Hobyo SO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=hobyo
# ------------------------
# Proceesing: Request #  97  |  Ati TD
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ati
# ------------------------
# Proceesing: Request #  98  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: Request #  99  |  Kabanjahe ID
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kabanjahe
# ------------------------
# Proceesing: Request #  100  |  Kabalo CD
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kabalo
# ------------------------
# Proceesing: Request #  101  |  Naze NG
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=naze
# ------------------------
# Proceesing: Request #  102  |  Tocopilla CL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tocopilla
# ------------------------
# Proceesing: Request #  103  |  Faya SA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=faya
# ------------------------
# Proceesing: Request #  104  |  Port Elizabeth US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=port+elizabeth
# ------------------------
# Proceesing: Request #  105  |  Merauke ID
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=merauke
# ------------------------
# Proceesing: Request #  106  |  Morgan City US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=morgan+city
# ------------------------
# Proceesing: Request #  107  |  Jaisalmer IN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=jaisalmer
# ------------------------
# Proceesing: Request #  108  |  Aklavik CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=aklavik
# ------------------------
# Proceesing: Request #  109  |  Castro CL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=castro
# ------------------------
# Proceesing: Request #  110  |  Port Blair IN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=port+blair
# ------------------------
# Proceesing: Request #  111  |  Deputatskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=deputatskiy
# ------------------------
# Proceesing: Request #  112  |  Cherskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=cherskiy
# ------------------------
# Proceesing: Request #  113  |  Luderitz NA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=luderitz
# ------------------------
# Proceesing: Request #  114  |  Vanimo PG
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vanimo
# ------------------------
# Proceesing: Request #  115  |  Nikolskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=nikolskoye
# ------------------------
# Proceesing: Request #  116  |  Pimenta Bueno BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=pimenta+bueno
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  117  |  Leningradskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=leningradskiy
# ------------------------
# Proceesing: Request #  118  |  Kidal ML
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kidal
# ------------------------
# Proceesing: Request #  119  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: Request #  120  |  Kodinsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kodinsk
# ------------------------
# Proceesing: Request #  121  |  Bonavista CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bonavista
# ------------------------
# Proceesing: Request #  122  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: Request #  123  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=saskylakh
# ------------------------
# Proceesing: Request #  124  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kodiak
# ------------------------
# Proceesing: Request #  125  |  Juruti BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=juruti
# ------------------------
# Proceesing: Request #  126  |  Vostok RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vostok
# ------------------------
# Proceesing: Request #  127  |  Toguchin RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=toguchin
# ------------------------
# Proceesing: Request #  128  |  Adelaide AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=adelaide
# ------------------------
# Proceesing: Request #  129  |  Tevaitoa PF
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tevaitoa
# ------------------------
# Proceesing: Request #  130  |  Cedral MX
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=cedral
# ------------------------
# Proceesing: Request #  131  |  Ust-Tsilma RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ust-tsilma
# ------------------------
# Proceesing: Request #  132  |  Namibe AO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=namibe
# ------------------------
# Proceesing: Request #  133  |  Pauini BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=pauini
# ------------------------
# Proceesing: Request #  134  |  Sal Rei CV
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sal+rei
# ------------------------
# Proceesing: Request #  135  |  Yumen CN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=yumen
# ------------------------
# Proceesing: Request #  136  |  Dhar IN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=dhar
# ------------------------
# Proceesing: Request #  137  |  Santa Maria da Vitoria BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=santa+maria+da+vitoria
# ------------------------
# Proceesing: Request #  138  |  Eureka US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=eureka
# ------------------------
# Proceesing: Request #  139  |  Acapulco MX
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=acapulco
# ------------------------
# Proceesing: Request #  140  |  Urengoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=urengoy
# ------------------------
# Proceesing: Request #  141  |  Tourlaville FR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tourlaville
# ------------------------
# Proceesing: Request #  142  |  Forestville CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=forestville
# ------------------------
# Proceesing: Request #  143  |  Worland US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=worland
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  144  |  Qaqortoq GL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=qaqortoq
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  145  |  Phan Thiet VN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=phan+thiet
# ------------------------
# Proceesing: Request #  146  |  Yulara AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=yulara
# ------------------------
# Proceesing: Request #  147  |  Saint George GR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=saint+george
# ------------------------
# Proceesing: Request #  148  |  Lyngseidet NO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=lyngseidet
# ------------------------
# Proceesing: Request #  149  |  Port Macquarie AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=port+macquarie
# ------------------------
# Proceesing: Request #  150  |  Ilulissat GL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ilulissat
# ------------------------
# Proceesing: Request #  151  |  Irondequoit US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=irondequoit
# ------------------------
# Proceesing: Request #  152  |  Zig US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=zig
# ------------------------
# Proceesing: Request #  153  |  Sao Filipe CV
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sao+filipe
# ------------------------
# Proceesing: Request #  154  |  Norman Wells CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=norman+wells
# ------------------------
# Proceesing: Request #  155  |  Mbanza-Ngungu CD
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mbanza-ngungu
# ------------------------
# Proceesing: Request #  156  |  Severo-Kurilsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=severo-kurilsk
# ------------------------
# Proceesing: Request #  157  |  Thiruvananthapuram IN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=thiruvananthapuram
# ------------------------
# Proceesing: Request #  158  |  Aksu KZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=aksu
# ------------------------
# Proceesing: Request #  159  |  Camacha PT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=camacha
# ------------------------
# Proceesing: Request #  160  |  Arcata US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=arcata
# ------------------------
# Proceesing: Request #  161  |  Barcelos PT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=barcelos
# ------------------------
# Proceesing: Request #  162  |  Sampit ID
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sampit
# ------------------------
# Proceesing: Request #  163  |  Mosquera CO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mosquera
# ------------------------
# Proceesing: Request #  164  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: Request #  165  |  Itapirapua BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=itapirapua
# ------------------------
# Proceesing: Request #  166  |  Vilhena BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vilhena
# ------------------------
# Proceesing: Request #  167  |  Los Llanos de Aridane ES
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=los+llanos+de+aridane
# ------------------------
# Proceesing: Request #  168  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=dikson
# ------------------------
# Proceesing: Request #  169  |  Kalispell US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kalispell
# ------------------------
# Proceesing: Request #  170  |  Yar-Sale RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=yar-sale
# ------------------------
# Proceesing: Request #  171  |  Petropavlovsk-Kamchatskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=petropavlovsk-kamchatskiy
# ------------------------
# Proceesing: Request #  172  |  Tarko-Sale RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tarko-sale
# ------------------------
# Proceesing: Request #  173  |  Cabo San Lucas MX
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=cabo+san+lucas
# ------------------------
# Proceesing: Request #  174  |  Adrar DZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=adrar
# ------------------------
# Proceesing: Request #  175  |  Natchez US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=natchez
# ------------------------
# Proceesing: Request #  176  |  Indiana US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=indiana
# ------------------------
# Proceesing: Request #  177  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=hermanus
# ------------------------
# Proceesing: Request #  178  |  Florianopolis BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=florianopolis
# ------------------------
# Proceesing: Request #  179  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ribeira+grande
# ------------------------
# Proceesing: Request #  180  |  Carnarvon ZA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=carnarvon
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  181  |  Kaitangata NZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kaitangata
# ------------------------
# Proceesing: Request #  182  |  Ayan TR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ayan
# ------------------------
# Proceesing: Request #  183  |  Islahiye TR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=islahiye
# ------------------------
# Proceesing: Request #  184  |  Dukat RS
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=dukat
# ------------------------
# Proceesing: Request #  185  |  Marsa Matruh EG
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=marsa+matruh
# ------------------------
# Proceesing: Request #  186  |  Tazovskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tazovskiy
# ------------------------
# Proceesing: Request #  187  |  Usogorsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=usogorsk
# ------------------------
# Proceesing: Request #  188  |  Vondrozo MG
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vondrozo
# ------------------------
# Proceesing: Request #  189  |  Soeng Sang TH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=soeng+sang
# ------------------------
# Proceesing: Request #  190  |  Guerrero Negro MX
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=guerrero+negro
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  191  |  Verkhoyansk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=verkhoyansk
# ------------------------
# Proceesing: Request #  192  |  Shitanjing CN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=shitanjing
# ------------------------
# Proceesing: Request #  193  |  Haines Junction CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=haines+junction
# ------------------------
# Proceesing: Request #  194  |  Pandan PH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=pandan
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  195  |  Kruisfontein ZA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kruisfontein
# ------------------------
# Proceesing: Request #  196  |  Verkhnevilyuysk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=verkhnevilyuysk
# ------------------------
# Proceesing: Request #  197  |  Bethel US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bethel
# ------------------------
# Proceesing: Request #  198  |  Carutapera BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=carutapera
# ------------------------
# Proceesing: Request #  199  |  Hofn IS
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=hofn
# ------------------------
# Proceesing: Request #  200  |  Altamira BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=altamira
# ------------------------
# Proceesing: Request #  201  |  Itarema BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=itarema
# ------------------------
# Proceesing: Request #  202  |  Kysyl-Syr RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kysyl-syr
# ------------------------
# Proceesing: Request #  203  |  Maragogi BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=maragogi
# ------------------------
# Proceesing: Request #  204  |  Souillac FR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=souillac
# ------------------------
# Proceesing: Request #  205  |  Jalu LY
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=jalu
# ------------------------
# Proceesing: Request #  206  |  Ostrovnoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ostrovnoy
# ------------------------
# Proceesing: Request #  207  |  Tapes BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tapes
# ------------------------
# Proceesing: Request #  208  |  Alofi NU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=alofi
# ------------------------
# Proceesing: Request #  209  |  Hambantota LK
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=hambantota
# ------------------------
# Proceesing: Request #  210  |  Kermanshah IR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kermanshah
# ------------------------
# Proceesing: Request #  211  |  Tanete ID
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tanete
# ------------------------
# Proceesing: Request #  212  |  Lompoc US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=lompoc
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  213  |  Kulmbach DE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kulmbach
# ------------------------
# Proceesing: Request #  214  |  Arroyo US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=arroyo
# ------------------------
# Proceesing: Request #  215  |  Sao Joao da Barra BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sao+joao+da+barra
# ------------------------
# Proceesing: Request #  216  |  Meulaboh ID
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=meulaboh
# ------------------------
# Proceesing: Request #  217  |  Loandjili CG
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=loandjili
# ------------------------
# Proceesing: Request #  218  |  Vyazma RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vyazma
# ------------------------
# Proceesing: Request #  219  |  Platteville US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=platteville
# Request not found, skipping...
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  220  |  Buala SB
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=buala
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  221  |  Ahipara NZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ahipara
# ------------------------
# Proceesing: Request #  222  |  Teahupoo PF
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=teahupoo
# ------------------------
# Proceesing: Request #  223  |  Constitucion MX
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=constitucion
# ------------------------
# Proceesing: Request #  224  |  Ponta Delgada PT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ponta+delgada
# ------------------------
# Proceesing: Request #  225  |  Rome IT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=roma
# ------------------------
# Proceesing: Request #  226  |  Chokurdakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=chokurdakh
# ------------------------
# Proceesing: Request #  227  |  Bay Roberts CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bay+roberts
# ------------------------
# Proceesing: Request #  228  |  Ganzhou CN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ganzhou
# ------------------------
# Proceesing: Request #  229  |  Boguchany RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=boguchany
# ------------------------
# Proceesing: Request #  230  |  Predivinsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=predivinsk
# ------------------------
# Proceesing: Request #  231  |  Vardo US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vardo
# ------------------------
# Proceesing: Request #  232  |  Anito PH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=anito
# ------------------------
# Proceesing: Request #  233  |  Vila Franca do Campo PT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vila+franca+do+campo
# ------------------------
# Proceesing: Request #  234  |  Port Hedland AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=port+hedland
# ------------------------
# Proceesing: Request #  235  |  Vitim RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vitim
# ------------------------
# Proceesing: Request #  236  |  Grand Gaube MU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=grand+gaube
# ------------------------
# Proceesing: Request #  237  |  Quatre Cocos MU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=quatre+cocos
# ------------------------
# Proceesing: Request #  238  |  Dallas US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=dallas
# ------------------------
# Proceesing: Request #  239  |  Hasaki JP
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=hasaki
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  240  |  Provideniya RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=provideniya
# ------------------------
# Proceesing: Request #  241  |  Karratha AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=karratha
# ------------------------
# Proceesing: Request #  242  |  Goure NE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=goure
# ------------------------
# Proceesing: Request #  243  |  Ust-Karsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ust-karsk
# ------------------------
# Proceesing: Request #  244  |  Sinjar SY
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sinjar
# ------------------------
# Proceesing: Request #  245  |  Esperance TT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=esperance
# ------------------------
# Proceesing: Request #  246  |  Waingapu ID
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=waingapu
# ------------------------
# Proceesing: Request #  247  |  Maralal KE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=maralal
# ------------------------
# Proceesing: Request #  248  |  Tiksi RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tiksi
# ------------------------
# Proceesing: Request #  249  |  Hwange ZW
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=hwange
# ------------------------
# Proceesing: Request #  250  |  Seoul KR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=seoul
# ------------------------
# Proceesing: Request #  251  |  Kenai US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kenai
# ------------------------
# Proceesing: Request #  252  |  Verkhnyaya Inta RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=verkhnyaya+inta
# ------------------------
# Proceesing: Request #  253  |  Kokkola FI
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kokkola
# ------------------------
# Proceesing: Request #  254  |  Albanel CA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=albanel
# ------------------------
# Proceesing: Request #  255  |  Nemuro JP
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=nemuro
# ------------------------
# Proceesing: Request #  256  |  Bonanza NI
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bonanza
# ------------------------
# Proceesing: Request #  257  |  Lorengau PG
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=lorengau
# ------------------------
# Proceesing: Request #  258  |  Marsabit KE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=marsabit
# ------------------------
# Proceesing: Request #  259  |  Siwana IN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=siwana
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  260  |  Svetlogorsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=svetlogorsk
# ------------------------
# Proceesing: Request #  261  |  Szamotuly PL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=szamotuly
# ...
# ------------------------
# Proceesing: Request #  462  |  Atar MR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=atar
# ------------------------
# Proceesing: Request #  463  |  Umm Lajj SA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=umm+lajj
# ------------------------
# Proceesing: Request #  464  |  Lagunas PE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=lagunas
# ------------------------
# Proceesing: Request #  465  |  Praia BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=praia
# ------------------------
# Proceesing: Request #  466  |  Aktau KZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=aktau
# ------------------------
# Proceesing: Request #  467  |  Pitea SE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=pitea
# ------------------------
# Proceesing: Request #  468  |  Vao EE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vao
# ------------------------
# Proceesing: Request #  469  |  Baculin PH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=baculin
# ------------------------
# Proceesing: Request #  470  |  Vibo Valentia IT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vibo+valentia
# ------------------------
# Proceesing: Request #  471  |  San Cristobal EC
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=san+cristobal
# ------------------------
# Proceesing: Request #  472  |  Karsun RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=karsun
# ------------------------
# Proceesing: Request #  473  |  Karasjok NO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=karasjok
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  474  |  Talaya RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=talaya
# ------------------------
# Proceesing: Request #  475  |  Caucaia BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=caucaia
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  476  |  Srednekolymsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=srednekolymsk
# ------------------------
# Proceesing: Request #  477  |  Ballesteros PH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ballesteros
# ------------------------
# Proceesing: Request #  478  |  Yanaul RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=yanaul
# ------------------------
# Proceesing: Request #  479  |  Kahului US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kahului
# ------------------------
# Proceesing: Request #  480  |  Batagay RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=batagay
# ------------------------
# Proceesing: Request #  481  |  Zlobin HR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=zlobin
# ------------------------
# Proceesing: Request #  482  |  Ojinaga US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ojinaga
# ------------------------
# Proceesing: Request #  483  |  Grand-Lahou CI
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=grand-lahou
# ------------------------
# Proceesing: Request #  484  |  Roald NO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=roald
# ------------------------
# Proceesing: Request #  485  |  Baykit RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=baykit
# ------------------------
# Proceesing: Request #  486  |  Fuerte PH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=fuerte
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  487  |  Fairbanks US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=fairbanks
# ------------------------
# Proceesing: Request #  488  |  Bathsheba BB
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bathsheba
# ------------------------
# Proceesing: Request #  489  |  Matamoros US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=matamoros
# ------------------------
# Proceesing: Request #  490  |  Hervey Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=hervey+bay
# ------------------------
# Proceesing: Request #  491  |  Bahia de Caraquez EC
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bahia+de+caraquez
# ------------------------
# Proceesing: Request #  492  |  Vangaindrano MG
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=vangaindrano
# ------------------------
# Proceesing: Request #  493  |  LUGOBA TZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=lugoba
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  494  |  Severodvinsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=severodvinsk
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  495  |  Alugan PH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=alugan
# ------------------------
# Proceesing: Request #  496  |  Westport IE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=westport
# ------------------------
# Proceesing: Request #  497  |  Santa Cruz US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=santa+cruz
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  498  |  Constantine DZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=constantine
# ------------------------
# Proceesing: Request #  499  |  Sam Roi Yot TH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sam+roi+yot
# ------------------------
# Proceesing: Request #  500  |  Portland US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=portland
# ------------------------
# Proceesing: Request #  501  |  Praia da Vitoria PT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=praia+da+vitoria
# ------------------------
# Proceesing: Request #  502  |  Poum MK
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=poum
# ------------------------
# Proceesing: Request #  503  |  Muisne EC
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=muisne
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  504  |  Zarinsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=zarinsk
# ------------------------
# Proceesing: Request #  505  |  Fayaoue NC
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=fayaoue
# ------------------------
# Proceesing: Request #  506  |  Kasama ZM
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kasama
# ------------------------
# Proceesing: Request #  507  |  Point Pleasant US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=point+pleasant
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  508  |  Akdepe TM
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=akdepe
# ------------------------
# Proceesing: Request #  509  |  College US
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=college
# ------------------------
# Proceesing: Request #  510  |  Goundam ML
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=goundam
# ------------------------
# Proceesing: Request #  511  |  Klaksvik FO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=klaksvik
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  512  |  Isangel VU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=isangel
# ------------------------
# Proceesing: Request #  513  |  Taguatinga BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=taguatinga
# ------------------------
# Proceesing: Request #  514  |  Camara de Lobos PT
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=camara+de+lobos
# ------------------------
# Proceesing: Request #  515  |  Kamenka RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=kamenka
# ------------------------
# Proceesing: Request #  516  |  Paciran ID
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=paciran
# ------------------------
# Proceesing: Request #  517  |  Karamadai IN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=karamadai
# ------------------------
# Proceesing: Request #  518  |  Mwense ZM
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mwense
# ------------------------
# Proceesing: Request #  519  |  Laukaa FI
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=laukaa
# ------------------------
# Proceesing: Request #  520  |  Sakaiminato JP
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sakaiminato
# ------------------------
# Proceesing: Request #  521  |  Maniitsoq GL
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=maniitsoq
# ------------------------
# Proceesing: Request #  522  |  Tual ID
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tual
# ------------------------
# Proceesing: Request #  523  |  Tafresh IR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=tafresh
# ------------------------
# Proceesing: Request #  524  |  San Quintin PH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=san+quintin
# ------------------------
# Proceesing: Request #  525  |  Sainte-Suzanne CH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sainte-suzanne
# ------------------------
# Proceesing: Request #  526  |  Darhan MN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=darhan
# ------------------------
# Proceesing: Request #  527  |  Cuamba MZ
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=cuamba
# ------------------------
# Proceesing: Request #  528  |  Linjiang CN
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=linjiang
# ------------------------
# Proceesing: Request #  529  |  Sibu MY
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sibu
# ------------------------
# Proceesing: Request #  530  |  Noyabrsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=noyabrsk
# ------------------------
# Proceesing: Request #  531  |  Juazeiro BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=juazeiro
# ------------------------
# Proceesing: Request #  532  |  Mao DO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mao
# ------------------------
# Proceesing: Request #  533  |  Nizwa OM
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=nizwa
# ------------------------
# Proceesing: Request #  534  |  Minab IR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=minab
# ------------------------
# Proceesing: Request #  535  |  Bacolod PH
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=bacolod
# ------------------------
# Proceesing: Request #  536  |  Mogadishu SO
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mogadishu
# ------------------------
# Proceesing: Request #  537  |  Ekhabi RU
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ekhabi
# ------------------------
# Proceesing: Request #  538  |  Intipuca SV
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=intipuca
# Request not found, skipping...
# ------------------------
# Proceesing: Request #  539  |  Plettenberg Bay ZA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=plettenberg+bay
# ------------------------
# Proceesing: Request #  540  |  Mahon IE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=mahon
# ------------------------
# Proceesing: Request #  541  |  Sambava MG
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=sambava
# ------------------------
# Proceesing: Request #  542  |  Ambulu ID
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=ambulu
# ------------------------
# Proceesing: Request #  543  |  Knysna ZA
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=knysna
# ------------------------
# Proceesing: Request #  544  |  Thinadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=thinadhoo
# ------------------------
# Proceesing: Request #  545  |  Xaxim BR
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=xaxim
# ------------------------
# Proceesing: Request #  546  |  Marsh Harbour BS
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=marsh+harbour
# ------------------------
# Proceesing: Request #  547  |  Skibbereen IE
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=skibbereen
# ------------------------
# Proceesing: Request #  548  |  Angoram PG
# http://api.openweathermap.org/data/2.5/weather?appid=924de882fad87c2864f771a725b6ae71&units=IMPERIAL&q=angoram

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#check size
cities_weather.count()
# Out:
# City                612
# Country             548
# Temperature (F)     548
# Latitude            548
# Longitude           548
# Humidity (%)        548
# Cloudiness (%)      548
# Wind Speed (mph)    548
# dtype: int64

# %%
#Drop unfound cities
cities_weather=cities_weather.dropna()
cities_weather.count()
# Out:
# City                548
# Country             548
# Temperature (F)     548
# Latitude            548
# Longitude           548
# Humidity (%)        548
# Cloudiness (%)      548
# Wind Speed (mph)    548
# dtype: int64

# %%
#export to csv and display dataframe
cities_weather.to_csv("./output_data/cities_weather.csv")
cities_weather.head(10)
# Out:
#               City Country  Temperature (F)  Latitude  Longitude  \
# 0  Arraial do Cabo      BR            80.25    -22.97     -42.02
# 1           Albany      US            35.58     42.65     -73.75
# 2          Rikitea      PF            76.02    -23.12    -134.97
# 3       Georgetown      GY            79.65      6.80     -58.16
# 4            Airai      TL            72.78     -8.93     125.41
# 5        Busselton      AU            59.63    -33.64     115.35
# 6            Gamba      CN           -12.77     28.28      88.52
# 7          Peniche      PT            55.47     39.36      -9.38
# 8      Kloulklubed      PW            77.00      7.04     134.26
# 9       Port Hardy      CA            44.60     50.70    -127.42
#
#    Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0          93.0            36.0              6.53
# 1          80.0            90.0              4.70
# 2         100.0            80.0             15.14
# 3          78.0            20.0             11.41
# 4          82.0            92.0              1.39
# 5          60.0            20.0             11.79
# 6          43.0             0.0              1.95
# 7          87.0            20.0             17.22
# 8          88.0            90.0             10.29
# 9          60.0            90.0             11.41

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
